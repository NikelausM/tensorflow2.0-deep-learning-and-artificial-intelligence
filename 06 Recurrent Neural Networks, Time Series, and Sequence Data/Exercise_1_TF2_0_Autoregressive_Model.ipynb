# %%
# Install TensorFlow
#!pip install tensorflow

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 2.2.0

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Create Data

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.title("Sinusoidal Wave")
plt.xlabel("Theta")
plt.ylabel("Amplitude")
plt.show()

# %%
# let's see if we can use T past values to predict the next value
T = 10 # 10 previous time steps to predict the next time step
X = []# Using fixed size numpy arrays would probably be better
Y = []

# Final target index: len(series) - 1
# Final t: len(series) - T - 1
# Final target index: Final t + T
# If we plug in value of little t ...
# Final target index: [len(series) - T - 1] + T
# Final target index: len(series) - 1
for t in range(len(series) - T): # 0 to len(series) - T - 1
  x = series[t:T+t] # t to t + T - 1
  X.append(x)
  y = series[t+T] # t + T
  Y.append(y)

X = np.array(X).reshape(-1, T) # Change from N x D to N x T
Y = np.array(Y)
N = len(X)
print(N)
print(X.shape)
print(Y.shape)
X_train = X[:-N//2]
X_test = X[-N//2:]
Y_train = Y[:-N//2]
Y_test = Y[-N//2:]
print(X_train.shape, ",",X_test.shape,",",Y_train.shape,",", Y_test.shape)
# Out:
# 190
# (190, 10)
# (190,)
# (95, 10) , (95, 10) , (95,) , (95,)

# %% [markdown]
# # Build Model

# %%
i = Input(shape=(T,))
x = Dense(1)(i)

model = Model(i, x)

model.compile(optimizer=Adam(lr=0.1),
              loss='mse',
               metrics=['accuracy'])

# %%
r = model.fit(X_train, Y_train,
              validation_data = (X_test, Y_test),
              epochs=90)
# Out:
# Epoch 1/90
# 3/3 [==============================] - 0s 32ms/step - loss: 0.9772 - accuracy: 0.0000e+00 - val_loss: 0.3893 - val_accuracy: 0.0000e+00
# Epoch 2/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.7535 - accuracy: 0.0000e+00 - val_loss: 0.4489 - val_accuracy: 0.0000e+00
# Epoch 3/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.3106 - accuracy: 0.0000e+00 - val_loss: 0.1068 - val_accuracy: 0.0000e+00
# Epoch 4/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1966 - accuracy: 0.0000e+00 - val_loss: 0.2297 - val_accuracy: 0.0000e+00
# Epoch 5/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.2675 - accuracy: 0.0000e+00 - val_loss: 0.0675 - val_accuracy: 0.0000e+00
# Epoch 6/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0650 - accuracy: 0.0000e+00 - val_loss: 0.1022 - val_accuracy: 0.0000e+00
# Epoch 7/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1065 - accuracy: 0.0000e+00 - val_loss: 0.1016 - val_accuracy: 0.0000e+00
# Epoch 8/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0793 - accuracy: 0.0000e+00 - val_loss: 0.0314 - val_accuracy: 0.0000e+00
# Epoch 9/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0540 - accuracy: 0.0000e+00 - val_loss: 0.0884 - val_accuracy: 0.0000e+00
# Epoch 10/90
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0784 - accuracy: 0.0000e+00 - val_loss: 0.0594 - val_accuracy: 0.0000e+00
# Epoch 11/90
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0400 - accuracy: 0.0000e+00 - val_loss: 0.0365 - val_accuracy: 0.0000e+00
# Epoch 12/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0532 - accuracy: 0.0000e+00 - val_loss: 0.0422 - val_accuracy: 0.0000e+00
# Epoch 13/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0463 - accuracy: 0.0000e+00 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 14/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0328 - accuracy: 0.0000e+00 - val_loss: 0.0281 - val_accuracy: 0.0000e+00
# Epoch 15/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0335 - accuracy: 0.0000e+00 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 16/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0271 - accuracy: 0.0000e+00 - val_loss: 0.0264 - val_accuracy: 0.0000e+00
# Epoch 17/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0303 - accuracy: 0.0000e+00 - val_loss: 0.0231 - val_accuracy: 0.0000e+00
# Epoch 18/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0282 - accuracy: 0.0000e+00 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 19/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0281 - accuracy: 0.0000e+00 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 20/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0261 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 21/90
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0257 - accuracy: 0.0000e+00 - val_loss: 0.0209 - val_accuracy: 0.0000e+00
# Epoch 22/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0254 - accuracy: 0.0000e+00 - val_loss: 0.0200 - val_accuracy: 0.0000e+00
# Epoch 23/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0251 - accuracy: 0.0000e+00 - val_loss: 0.0198 - val_accuracy: 0.0000e+00
# Epoch 24/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0239 - accuracy: 0.0000e+00 - val_loss: 0.0204 - val_accuracy: 0.0000e+00
# Epoch 25/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0249 - accuracy: 0.0000e+00 - val_loss: 0.0197 - val_accuracy: 0.0000e+00
# Epoch 26/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0234 - accuracy: 0.0000e+00 - val_loss: 0.0197 - val_accuracy: 0.0000e+00
# Epoch 27/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0235 - accuracy: 0.0000e+00 - val_loss: 0.0190 - val_accuracy: 0.0000e+00
# Epoch 28/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0223 - accuracy: 0.0000e+00 - val_loss: 0.0185 - val_accuracy: 0.0000e+00
# Epoch 29/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0219 - accuracy: 0.0000e+00 - val_loss: 0.0184 - val_accuracy: 0.0000e+00
# Epoch 30/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0220 - accuracy: 0.0000e+00 - val_loss: 0.0180 - val_accuracy: 0.0000e+00
# Epoch 31/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0220 - accuracy: 0.0000e+00 - val_loss: 0.0177 - val_accuracy: 0.0000e+00
# Epoch 32/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0209 - accuracy: 0.0000e+00 - val_loss: 0.0175 - val_accuracy: 0.0000e+00
# Epoch 33/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0212 - accuracy: 0.0000e+00 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 34/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0205 - accuracy: 0.0000e+00 - val_loss: 0.0171 - val_accuracy: 0.0000e+00
# Epoch 35/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0210 - accuracy: 0.0000e+00 - val_loss: 0.0170 - val_accuracy: 0.0000e+00
# Epoch 36/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0203 - accuracy: 0.0000e+00 - val_loss: 0.0170 - val_accuracy: 0.0000e+00
# Epoch 37/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0199 - accuracy: 0.0000e+00 - val_loss: 0.0165 - val_accuracy: 0.0000e+00
# Epoch 38/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0196 - accuracy: 0.0000e+00 - val_loss: 0.0169 - val_accuracy: 0.0000e+00
# Epoch 39/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0193 - accuracy: 0.0000e+00 - val_loss: 0.0161 - val_accuracy: 0.0000e+00
# Epoch 40/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0190 - accuracy: 0.0000e+00 - val_loss: 0.0161 - val_accuracy: 0.0000e+00
# Epoch 41/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0189 - accuracy: 0.0000e+00 - val_loss: 0.0157 - val_accuracy: 0.0000e+00
# Epoch 42/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0187 - accuracy: 0.0000e+00 - val_loss: 0.0155 - val_accuracy: 0.0000e+00
# Epoch 43/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0182 - accuracy: 0.0000e+00 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 44/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0179 - accuracy: 0.0000e+00 - val_loss: 0.0152 - val_accuracy: 0.0000e+00
# Epoch 45/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0188 - accuracy: 0.0000e+00 - val_loss: 0.0153 - val_accuracy: 0.0000e+00
# Epoch 46/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0180 - accuracy: 0.0000e+00 - val_loss: 0.0154 - val_accuracy: 0.0000e+00
# Epoch 47/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0179 - accuracy: 0.0000e+00 - val_loss: 0.0148 - val_accuracy: 0.0000e+00
# Epoch 48/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0173 - accuracy: 0.0000e+00 - val_loss: 0.0147 - val_accuracy: 0.0000e+00
# Epoch 49/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0180 - accuracy: 0.0000e+00 - val_loss: 0.0148 - val_accuracy: 0.0000e+00
# Epoch 50/90
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0174 - accuracy: 0.0000e+00 - val_loss: 0.0146 - val_accuracy: 0.0000e+00
# Epoch 51/90
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0171 - accuracy: 0.0000e+00 - val_loss: 0.0145 - val_accuracy: 0.0000e+00
# Epoch 52/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0177 - accuracy: 0.0000e+00 - val_loss: 0.0145 - val_accuracy: 0.0000e+00
# Epoch 53/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0173 - accuracy: 0.0000e+00 - val_loss: 0.0151 - val_accuracy: 0.0000e+00
# Epoch 54/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0170 - accuracy: 0.0000e+00 - val_loss: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 55/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 0.0000e+00 - val_loss: 0.0149 - val_accuracy: 0.0000e+00
# Epoch 56/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0148 - val_accuracy: 0.0000e+00
# Epoch 57/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0178 - accuracy: 0.0000e+00 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 58/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0160 - accuracy: 0.0000e+00 - val_loss: 0.0136 - val_accuracy: 0.0000e+00
# Epoch 59/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0159 - accuracy: 0.0000e+00 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 60/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 61/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0166 - accuracy: 0.0000e+00 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 62/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0157 - accuracy: 0.0000e+00 - val_loss: 0.0137 - val_accuracy: 0.0000e+00
# Epoch 63/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0155 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 64/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 0.0000e+00 - val_loss: 0.0131 - val_accuracy: 0.0000e+00
# Epoch 65/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0153 - accuracy: 0.0000e+00 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 66/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0134 - val_accuracy: 0.0000e+00
# Epoch 67/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0161 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 68/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0153 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 69/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0151 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 70/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0149 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 71/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0148 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 72/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 0.0000e+00 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 73/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 74/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0145 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 0.0000e+00
# Epoch 75/90
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0164 - accuracy: 0.0000e+00 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 76/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0157 - accuracy: 0.0000e+00 - val_loss: 0.0139 - val_accuracy: 0.0000e+00
# Epoch 77/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0135 - val_accuracy: 0.0000e+00
# Epoch 78/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0153 - accuracy: 0.0000e+00 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 79/90
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0133 - val_accuracy: 0.0000e+00
# Epoch 80/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0149 - accuracy: 0.0000e+00 - val_loss: 0.0126 - val_accuracy: 0.0000e+00
# Epoch 81/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 82/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0145 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 83/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0145 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 84/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0141 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 85/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0143 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 86/90
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0142 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 87/90
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0142 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 88/90
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0141 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 89/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0145 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 90/90
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0140 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00

# %% [markdown]
# # Evaluate Model

# %%
# Plot the loss
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.title("Loss and Validation Loss vs. Epoch")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

# %%
# Single step forecast (wrong way)
predictions_test = []
i = -N//2
while (len(predictions_test) < len(Y_test)):
  p = model.predict(X[i].reshape(1, -1))[0,0]
  i += 1

  predictions_test.append(p)

# %%
plt.plot(Y_test, label='forecast target')
plt.plot(predictions_test, label='forecast prediction')
plt.title("Single Step Forecast")
plt.ylabel('Amplitude')
plt.xlabel('Theta')
plt.legend()

# %%
# Multi step forecast - uses predictions for making future predictions
predictions_test = []

# Last train input
x_last = X[-N//2]

while (len(predictions_test) < len(Y_test)):
  p = model.predict(x_last.reshape(1, -1))[0,0]
  i += 1

  predictions_test.append(p)

  # Shift x_last vector of T values by 1 value to the left
  x_last = np.roll(x_last, -1)
  # Make last x_last element the prediction
  x_last[-1] = p

# %%
plt.plot(Y_test, label='forecast target')
plt.plot(predictions_test, label='forecast prediction')
plt.title("Multi Step Forecast")
plt.ylabel('Amplitude')
plt.xlabel('Theta')
plt.legend()
