# %%
# Install TensorFlow
# !pip install -q tensorflow-gpu==2.0.0-beta1

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 2.2.0

# %%
# Other imports
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# # Create Dataset

# %%
N = 1000 # 1000 data points
X = np.random.random((N, 2)) * 6 -  3 # Samples of uniform distribution from -3 to 3
Y = np.cos(2 * X[:,0]) + np.cos(3 * X[:,1])

# %% [markdown]
# ## EDA

# %%
fig = plt.figure()
scatter_plt = fig.add_subplot(111, projection='3d')
scatter_plt.scatter(X[:,0], X[:,1], Y)

# %% [markdown]
# # Build Model

# %%
i = Input(shape=(2,))
x = Dense(128, activation='relu')(i)
x = Dense(1,)(x)

model = Model(i, x)

opt = Adam(0.01)

model.compile(optimizer=opt,
              loss='mse',)

# %%
r = model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9964
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9380
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9130
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8880
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8617
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8135
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7414
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6763
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6437
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5867
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5354
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5280
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4778
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5310
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5118
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4852
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4514
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4965
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4970
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4837
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4517
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4453
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4468
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4734
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3946
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4065
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3783
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4165
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3874
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3919
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3207
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3060
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3169
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2754
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2618
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2336
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1960
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1766
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1682
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1647
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1310
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1320
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1010
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0892
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0785
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0789
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0667
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0502
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0550
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0468
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0622
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0368
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0317
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0262
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0377
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0182
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0139
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0186
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0154
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0109
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0119
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0191
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0204
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0102
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0085
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0079
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0098
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0101
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0530
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0471
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0452
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0102
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0073
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0079
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0122
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0076
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0202
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0109
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0168
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0146
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0146
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0125
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0063
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0108
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0223
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0191
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0159
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0212
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0103
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0119
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0188

# %% [markdown]
# # Evaluate Model

# %%
# Plot the loss
plt.plot(r.history['loss'], label='loss')
plt.title("Loss vs. Epoch")
plt.ylabel('Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# Plot prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# Surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
print("xx", xx)
print(xx.shape)
print("yy", yy)
print(yy.shape)
print("xx.flatten", xx.flatten())
print(xx.flatten().shape)
print('yy.flatten', yy.flatten())
print(yy.flatten().shape)
print('vstack', np.vstack((xx.flatten(), yy.flatten())))
print(np.vstack((xx.flatten(), yy.flatten())).shape)
print('vstack T', np.vstack((xx.flatten(), yy.flatten())).T)
print(np.vstack((xx.flatten(), yy.flatten())).T.shape)
print('Xgrid', Xgrid)
print(Xgrid.shape)
print("model.predict(Xgrid)")
print(model.predict(Xgrid))
print(model.predict(Xgrid).shape)
print("model.predict(Xgrid).flatten()")
print(model.predict(Xgrid).flatten())
print(model.predict(Xgrid).flatten().shape)
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
# Out:
# xx [[-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]
#  [-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]
#  [-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]
#  ...
#  [-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]
#  [-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]
#  [-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]]
# (50, 50)
# yy [[-3.         -3.         -3.         ... -3.         -3.
#   -3.        ]
#  [-2.87755102 -2.87755102 -2.87755102 ... -2.87755102 -2.87755102
#   -2.87755102]
#  [-2.75510204 -2.75510204 -2.75510204 ... -2.75510204 -2.75510204
#   -2.75510204]
#  ...
#  [ 2.75510204  2.75510204  2.75510204 ...  2.75510204  2.75510204
#    2.75510204]
#  [ 2.87755102  2.87755102  2.87755102 ...  2.87755102  2.87755102
#    2.87755102]
#  [ 3.          3.          3.         ...  3.          3.
#    3.        ]]
# (50, 50)
# xx.flatten [-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#   3.        ]
# (2500,)
# yy.flatten [-3. -3. -3. ...  3.  3.  3.]
# (2500,)
# vstack [[-3.         -2.87755102 -2.75510204 ...  2.75510204  2.87755102
#    3.        ]
#  [-3.         -3.         -3.         ...  3.          3.
#    3.        ]]
# (2, 2500)
# vstack T [[-3.         -3.        ]
#  [-2.87755102 -3.        ]
#  [-2.75510204 -3.        ]
#  ...
#  [ 2.75510204  3.        ]
#  [ 2.87755102  3.        ]
#  [ 3.          3.        ]]
# (2500, 2)
# Xgrid [[-3.         -3.        ]
#  [-2.87755102 -3.        ]
#  [-2.75510204 -3.        ]
#  ...
#  [ 2.75510204  3.        ]
#  [ 2.87755102  3.        ]
#  [ 3.          3.        ]]
# (2500, 2)
# model.predict(Xgrid)
# [[-0.05906898]
#  [-0.2763937 ]
#  [-0.4937275 ]
#  ...
#  [-0.33892018]
#  [-0.13437492]
#  [ 0.07017058]]
# (2500, 1)
# model.predict(Xgrid).flatten()
# [-0.05906898 -0.2763937  -0.4937275  ... -0.33892018 -0.13437492
#   0.07017058]
# (2500,)

# %%
# Extrapolating
# Plot prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# Surface plot
line = np.linspace(-7, 7, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
